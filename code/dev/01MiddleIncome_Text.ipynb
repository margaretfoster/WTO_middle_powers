# %% [markdown]
# This script to attempt to isolate "leadership" bids by UMC and LMC countries.
#
# Goal: use the speaker income tags to find words that are overrepresented in the paragraphs from each LMC and UMC with “meaningful” (aka: blue or green) activity patterns

# %%
import pandas as pd
import os
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print(os.getcwd()) ## check working directory

datapath = "../data/"
