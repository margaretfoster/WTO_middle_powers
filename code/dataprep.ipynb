# %%
## Overview of the WTO CTD Minutes Dataset

# %%
import pandas as pd
import os

# %%
datapath = os.path.dirname("../data/")

# %%
wto = pd.read_excel('../data/wtoCTDSpeakerParagraphMto117.xlsx',
                    engine="openpyxl", index_col=0)
# Out:
# /Users/Promachos/Dropbox (Personal)/WTO-Github/WTO-DataRelease/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
print(wto.shape) #(11737, 24)
print(wto.columns)
# Out:
# (11737, 23)
# Index(['paranum', 'paratext', 'doc', 'firstent', 'ents', 'speaker.change',
#        'isagenda', 'minutes.meta', 'behalf', 'date', 'year', 'meetingno',
#        'numdate', 'people', 'codes', 'Freq', 'country', 'region',
#        'income_level_iso3c', 'pres.speaker', 'pid', 'sample1',
#        'sample.subset'],
#       dtype='object')

# %% [markdown]
# ## Overview summary information:
#
# To cover:
# - Date range: 1995- 2022
# - Number of paragraphs: 11737
# - Summary over time of state vs non-state speakers: 4648 non-state; 7089 state
# - Number of speakers
# - Distribution of speakers across time
# - Time for country speakers across time (heatmap?)

# %%
print(wto[["meetingno", "year"]].min())
print(wto[["meetingno", "year"]].max())
# Out:
# meetingno       1
# year         1995
# dtype: int64
# meetingno     117
# year         2022
# dtype: int64
